# %%
# !pip install Bio-Epidemiology-NER

# %%
# load all the functions
from Bio_Epidemiology_NER.bio_recognizer import ner_prediction

# returns the predicted class along with the probability of the actual EnvBert model
doc = """
	CASE: A 28-year-old previously healthy man presented with a 6-week history of palpitations.
      The symptoms occurred during rest, 2–3 times per week, lasted up to 30 minutes at a time
      and were associated with dyspnea. Except for a grade 2/6 holosystolic tricuspid regurgitation
      murmur (best heard at the left sternal border with inspiratory accentuation), physical
      examination yielded unremarkable findings.
      """

# returns a dataframe output
df=ner_prediction(corpus=doc, compute='cpu') #pass compute='gpu' if using gpu
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/token_classification.py:169: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/Bio_Epidemiology_NER/bio_recognizer.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(disease_df) # adding the disease_df to existing
# /usr/local/lib/python3.10/dist-packages/Bio_Epidemiology_NER/bio_recognizer.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   master_df = master_df.append(final_df)
# ...

# %%
df
# Out:
#             entity_group                                              value  \
# 0                    Age                                        28-year-old
# 1                History                                 previously healthy
# 2                    Sex                                                man
# 3         Clinical_event                                          presented
# 4               Duration                                             6-week
# 5           Sign_symptom                                       palpitations
# 6            Coreference                                           symptoms
# 7              Frequency                                      2–3 times per
# 8   Detailed_description  up symptoms to 30 minutes at associated lasted...
# 9              Lab_value                                          grade 2/6
# 10  Detailed_description                                       holosystolic
# ...

# %%
# load all the functions
from Bio_Epidemiology_NER.bio_recognizer import ner_prediction

# returns the predicted class along with the probability of the actual EnvBert model
doc = """
	A person has a fever if their body temperature rises above the normal range of 98–100°F (36–37°C). It is a common sign of an infection.
      """

# returns a dataframe output
df=ner_prediction(corpus=doc, compute='cpu') #pass compute='gpu' if using gpu
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/token_classification.py:169: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/Bio_Epidemiology_NER/bio_recognizer.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(disease_df) # adding the disease_df to existing
# /usr/local/lib/python3.10/dist-packages/Bio_Epidemiology_NER/bio_recognizer.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   master_df = master_df.append(final_df)

# %%
df
# Out:
#            entity_group                   value     score
# 0          Sign_symptom                   fever  0.999948
# 1  Diagnostic_procedure        body temperature  0.999937
# 2             Lab_value  above their the normal  0.977411
# 3             Lab_value                98–100°F  0.997479
# 4             Lab_value        98–100°F 36–37°C  0.976440

# %%
# !pip install py2neo

# %%
# !pip install neo4j
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.3/192.3 kB 6.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for neo4j: filename=neo4j-5.13.0-py3-none-any.whl size=265313 sha256=ca817e8e9e149d8da595cf94c5bd3445d15ea616a500c5c4df5a8153b48c0c0a
#   Stored in directory: /root/.cache/pip/wheels/7b/1d/b6/1be3a1e9de57bc832b7fcebbbf884186d8155bb6f1cc45be99
# Successfully built neo4j
# ...

# %%
   uri = "neo4j+s://71041f2d.databases.neo4j.io"  # Change this to your Neo4j database URI
    username = "neo4j"
    password = "d7NBKR45Nrx8wMrKsUYwHTAsKv7xDVF1UNmaKUH_i74"

# %%
MATCH (s:Symptom {name: "fever "})-[:IS_SYMPTOM_OF]->(d:Disease)
RETURN s, d

# %%
from neo4j import GraphDatabase

# Define a function to fetch nodes related to a symptom
def fetch_symptom_related_nodes(symptom_name):
    # Define the Neo4j connection parameters
    uri = "neo4j+s://71041f2d.databases.neo4j.io"  # Replace with your Neo4j server URI
    username = "neo4j"
    password = "d7NBKR45Nrx8wMrKsUYwHTAsKv7xDVF1UNmaKUH_i74"

    # Define the Cypher query
    query = (
        "MATCH (s:Symptom {name: $symptom_name})-[:IS_SYMPTOM_OF]->(d:Disease) "
        "RETURN  s, d"
    )

    # Establish a connection to the database and execute the query
    with GraphDatabase.driver(uri, auth=(username, password)) as driver:
        with driver.session() as session:
            result = session.run(query, symptom_name=symptom_name)
            # Collect the results into a list of dictionaries
            results = [record.data() for record in result]

    return results

# Input symptom name
input_symptom = "severe pain "

# Call the function to fetch nodes related to the symptom
results = fetch_symptom_related_nodes(input_symptom)

unique_disease_nodes = set()
# if results!=' ':
for result in results:
    disease_node = result['d']
    unique_disease_nodes.add(disease_node['name'])

# Print the unique disease nodes
if unique_disease_nodes:
    print("Unique Disease Nodes:")
    for disease_name in unique_disease_nodes:
        print(f"Disease Node: {disease_name}")
else:
    print("No unique disease nodes found.")
# Out:
# Unique Disease Nodes:
# Disease Node: pancreatitis
# Disease Node: bone fracture
# Disease Node: sciatica
# Disease Node: sprained ankle
# Disease Node: migraine
# Disease Node: chronic pain
# Disease Node: endometriosis
# Disease Node: sprained knee
# Disease Node: arthritis
# Disease Node: plantar fasciitis
# Disease Node: kidney stone
# Disease Node: miscarriage
# Disease Node: diverticulitis
# Disease Node: cervical radiculopathy
# Disease Node: fibromyalgia
# Disease Node: encephalitis
# Disease Node: thoracic radiculopathy
# Disease Node: epididymitis
# Disease Node: sleep apnea
# Disease Node: burn
# Disease Node: low back pain
# Disease Node: abscess
# Disease Node: irritable bowel syndrome
# Disease Node: carpal tunnel syndrome
# Disease Node: sickle cell anemia
# Disease Node: gallstones

# %%
from neo4j import GraphDatabase

# Define a function to fetch nodes related to a symptom
def fetch_symptom_related_nodes(symptom_name):
    # Define the Neo4j connection parameters
    uri = "neo4j+s://71041f2d.databases.neo4j.io"  # Replace with your Neo4j server URI
    username = "neo4j"
    password = "d7NBKR45Nrx8wMrKsUYwHTAsKv7xDVF1UNmaKUH_i74"

    # Define the Cypher query
    query = (
        "MATCH (s:Symptom {name: $symptom_name})-[:IS_SYMPTOM_OF]->(d:Disease) "
        "RETURN  s, d"
    )

    # Establish a connection to the database and execute the query
    with GraphDatabase.driver(uri, auth=(username, password)) as driver:
        with driver.session() as session:
            result = session.run(query, symptom_name=symptom_name)
            # Collect the results into a list of dictionaries
            results = [record.data() for record in result]

    return results

# Input symptom name
input_symptom = "scar "

# Call the function to fetch nodes related to the symptom
results = fetch_symptom_related_nodes(input_symptom)

unique_disease_nodes = set()
# if results!=' ':
for result in results:
    disease_node = result['d']
    unique_disease_nodes.add(disease_node['name'])

# Print the unique disease nodes
if unique_disease_nodes:
    print("Unique Disease Nodes:")
    for disease_name in unique_disease_nodes:
        print(f"Disease Node: {disease_name}")
else:
    print("No unique disease nodes found.")
# Out:
# Unique Disease Nodes:
# Disease Node: plantar fasciitis
